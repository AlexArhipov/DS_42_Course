# %% [markdown]
# # Day 09. Exercise 02
# # Metrics

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
import numpy as np
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import GridSearchCV, ParameterGrid
from tqdm.notebook import tqdm
import pickle

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# 1. Create the same dataframe as in the previous exercise.
# 2. Using `train_test_split` with parameters `test_size=0.2`, `random_state=21` get `X_train`, `y_train`, `X_test`, `y_test`. Use the additional parameter `stratify`.

# %%
df = pd.read_csv('day-of-week-not-scaled.csv')
df
# Out:
#       numTrials  hour  ...  labname_laba06s  labname_project1
# 0             1     5  ...              0.0               1.0
# 1             2     5  ...              0.0               1.0
# 2             3     5  ...              0.0               1.0
# 3             4     5  ...              0.0               1.0
# 4             5     5  ...              0.0               1.0
# ...         ...   ...  ...              ...               ...
# 1681          9    20  ...              1.0               0.0
# 1682          6    20  ...              1.0               0.0
# 1683          7    20  ...              1.0               0.0
# 1684          8    20  ...              1.0               0.0
# 1685          9    20  ...              1.0               0.0
#
# [1686 rows x 44 columns]

# %%
X = df.drop('dayofweek', axis=1)
y = df['dayofweek']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=21)

# %% [markdown]
# ## 2. SVM

# %% [markdown]
# 1. Use the best parameters from the previous exercise and train the model of SVM.
# 2. You need to calculate `accuracy`, `precision`, `recall`, `ROC AUC`.
#
#  - `precision` and `recall` should be calculated for each class (use `average='weighted'`)
#  - `ROC AUC` should be calculated for each class against any other class (all possible pairwise combinations) and then weighted average should be applied for the final metric
#  - the code in the cell should display the result as below:
#
# ```
# accuracy is 0.88757
# precision is 0.89267
# recall is 0.88757
# roc_auc is 0.97878
# ```

# %%
model_svc = svm.SVC(C=10, gamma='auto', probability=True, random_state=21)
model_svc.fit(X_train, y_train)
pred = model_svc.predict(X_test)
score = model_svc.predict_proba(X_test)

# %%
print('accuracy is %.5f' %accuracy_score(y_test, pred))
print('precision is %.5f' %precision_score(y_test, pred, average='weighted'))
print('recall is %.5f' %recall_score(y_test, pred, average='weighted'))
print('roc_auc is %.5f' %roc_auc_score(y_test, score, average='weighted', multi_class='ovo'))
# Out:
# accuracy is 0.88757
# precision is 0.89267
# recall is 0.88757
# roc_auc is 0.97878

# %% [markdown]
# ## 3. Decision tree

# %% [markdown]
# 1. The same task for decision tree

# %%
model_tree = DecisionTreeClassifier(class_weight = 'balanced', max_depth =27, criterion='entropy')
model_tree.fit(X_train, y_train)
pred = model_tree.predict(X_test)
score = model_tree.predict_proba(X_test)

# %%
print('accuracy is %.5f' %accuracy_score(y_test, pred))
print('precision is %.5f' %precision_score(y_test, pred, average='weighted'))
print('recall is %.5f' %recall_score(y_test, pred, average='weighted'))
print('roc_auc is %.5f' %roc_auc_score(y_test, score, average='weighted', multi_class='ovo'))
# Out:
# accuracy is 0.89941
# precision is 0.90087
# recall is 0.89941
# roc_auc is 0.93829

# %% [markdown]
# ## 4. Random forest

# %% [markdown]
# 1. The same task for random forest.

# %%
model_random_forest = RandomForestClassifier(n_estimators =50, class_weight = None, max_depth = 32)
model_random_forest.fit(X_train, y_train)
pred = model_random_forest.predict(X_test)
score = model_random_forest.predict_proba(X_test)

# %%
print('accuracy is %.5f' %accuracy_score(y_test, pred))
print('precision is %.5f' %precision_score(y_test, pred, average='weighted'))
print('recall is %.5f' %recall_score(y_test, pred, average='weighted'))
print('roc_auc is %.5f' %roc_auc_score(y_test, score, average='weighted', multi_class='ovo'))
# Out:
# accuracy is 0.93195
# precision is 0.93310
# recall is 0.93195
# roc_auc is 0.98673

# %% [markdown]
# ## 5. Predictions

# %% [markdown]
# 1. Choose the best model.
# 2. Analyze: for which `weekday` your model makes the most errors (in % of the total number of samples of that class in your full dataset), for which `labname` and for which `users`.
# 3. Save the model.

# %%
view_test = X_test
view_test['predict'] = pred
view_test[y_test != pred]
# Out:
#       numTrials  hour  uid_user_0  ...  labname_laba06s  labname_project1  predict
# 1181         54    21         0.0  ...              0.0               1.0        0
# 1452         31    17         0.0  ...              0.0               1.0        1
# 814          29    14         0.0  ...              0.0               1.0        4
# 809           5    22         0.0  ...              0.0               1.0        5
# 117           2     7         0.0  ...              0.0               1.0        0
# 1618          1    17         0.0  ...              1.0               0.0        3
# 951          84    17         0.0  ...              0.0               1.0        4
# 98            8    22         0.0  ...              0.0               0.0        5
# 128           1    20         0.0  ...              0.0               0.0        6
# 204           2     0         0.0  ...              0.0               0.0        5
# 384           1     6         0.0  ...              0.0               0.0        5
# 101           1    13         0.0  ...              0.0               0.0        3
# 173          16    15         0.0  ...              0.0               0.0        4
# 1227          8    18         0.0  ...              0.0               1.0        3
# 74            7    15         0.0  ...              0.0               0.0        6
# 947           5    16         0.0  ...              0.0               1.0        5
# 1616          1    16         0.0  ...              0.0               0.0        6
# 648          19     8         0.0  ...              0.0               0.0        5
# 811           2    14         0.0  ...              0.0               1.0        3
# 336           1    21         0.0  ...              0.0               0.0        5
# 1628          1    10         0.0  ...              0.0               0.0        3
# 409           1    19         0.0  ...              0.0               0.0        5
#
# [22 rows x 44 columns]

# %%
filename = 'model_random_tree.sav'
pickle.dump(model_random_forest, open(filename, 'wb'))

# %% [markdown]
# ## 6. Function

# %% [markdown]
# 1. Write a function that takes a list of different models and a corresponding list of parameters (dicts) and returns a dict that contains all the 4 metrics for each model.

# %%
def print_metric(models, paramets):
    for model in models:
      model.set_params(paramets).fit(X_train, y_train)    
      pred = model.set_params(paramets).predict(X_test)
      score = model.set_params(paramets).predict_proba(X_test)
      return {'accuracy': accuracy_score(y_test, pred),
            'precision': precision_score(y_test, pred, average='weighted'),
            'recall': recall_score(y_test, pred, average='weighted'),
            'roc_auc': roc_auc_score(y_test, score, average='weighted', multi_class='ovo')}
